# %% [markdown]
# # Best Movie Genre of all Time

# %%
import pandas as pd

# %%
movieSheet = pd.read_csv("C:/Users/Alan/Desktop/MovieDataSet/movies_metadata.csv", encoding = 'utf-8')
# Out:
# C:\Users\Alan\anaconda3\envs\trial\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
movieSheet.keys()
#for this project im going to need to pull genre, release date, title, and revenue. im also going to keep this english films only
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
movie_DF = pd.DataFrame(movieSheet)

# %%
movie_DF
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      FALSE                                                NaN  65000000
# 2      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      FALSE                                                NaN  16000000
# 4      FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  FALSE                                                NaN         0
# 45462  FALSE                                                NaN         0
# 45463  FALSE                                                NaN         0
# 45464  FALSE                                                NaN         0
# 45465  FALSE                                                NaN         0
#
#                                                   genres  \
# ...

# %%
movie_DF.shape
# Out:
# (45466, 24)

# %%
movie_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
movie_DF.tail(4)
# Out:
#        adult belongs_to_collection budget  \
# 45462  FALSE                   NaN      0
# 45463  FALSE                   NaN      0
# 45464  FALSE                   NaN      0
# 45465  FALSE                   NaN      0
#
#                                                   genres homepage      id  \
# 45462                      [{'id': 18, 'name': 'Drama'}]      NaN  111109
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...      NaN   67758
# 45464                                                 []      NaN  227506
# 45465                                                 []      NaN  461257
#
#          imdb_id original_language       original_title  \
# 45462  tt2028550                tl  Siglo ng Pagluluwal
# 45463  tt0303758                en             Betrayal
# 45464  tt0008536                en  Satana likuyushchiy
# 45465  tt6980792                en             Queerama
#
#                                                 overview  ... release_date  \
# ...

# %%
from matplotlib import pyplot as plt
from datetime import datetime as dt
import seaborn as sns
import numpy as np

# %%
plt.plot(movie_DF['revenue'])

# %%
plt.plot(movie_DF['vote_average'])

# %%
x = movie_DF.loc[:, "real",]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\trial\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'real'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-db6f95507a51> in <module>
# ...

# %%
x
# Out:
# 0        373554033.0
# 1        262797249.0
# 2                0.0
# 3         81452156.0
# 4         76578911.0
#             ...
# 45461            0.0
# 45462            0.0
# 45463            0.0
# 45464            0.0
# 45465            0.0
# Name: revenue, Length: 45466, dtype: float64

# %%
x.isnull().sum()
# Out:
# 6

# %%
movie_DF.dropna(how='any').shape
# Out:
# (693, 24)

# %%
movie_DF.shape
# Out:
# (45466, 24)

# %%
y = movie_DF.dropna(how='any').shape

# %%
y
# Out:
# (693, 24)

# %%
moviesheet = pd.DataFrame(movieSheet, y)

# %%
moviesheet
# Out:
#      adult belongs_to_collection   budget  \
# 693  FALSE                   NaN        0
# 24   FALSE                   NaN  3600000
#
#                                                 genres  \
# 693  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 24   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                               homepage     id    imdb_id  \
# 693                                                NaN  10990  tt0117107
# 24   http://www.mgm.com/title_title.do?title_star=L...    451  tt0113627
#
#     original_language     original_title  \
# 693                en   Mulholland Falls
# 24                 en  Leaving Las Vegas
#
#                                               overview  ... release_date  \
# 693  In 1950s Los Angeles, a special crime squad of...  ...    4/26/1996
# 24   Ben Sanderson, an alcoholic Hollywood screenwr...  ...   10/27/1995
#
#         revenue runtime                          spoken_languages    status  \
# ...

# %%
Budget = movie_DF.loc[:, "budget"]

# %%
Budget
# Out:
# 0        30000000
# 1        65000000
# 2               0
# 3        16000000
# 4               0
#            ...
# 45461           0
# 45462           0
# 45463           0
# 45464           0
# 45465           0
# Name: budget, Length: 45466, dtype: object

# %%
movie_plot = plt.plot(movie_DF['revenue'])
plt.xlabel('movies')
plt.ylabel('revenue')
# Out:
# Text(0, 0.5, 'revenue')

# %%
plt.plot(movie_DF['budget'], movie_DF['revenue'])
plt.xlabel('movie')
plt.ylabel('revenue')
plt.show()

# %%
x = [movie_DF('title')]
y = [movie_DF('revenue')]
plt.plot(x, y)
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-e564073c091d> in <module>
# ----> 1 x = [movie_DF('title')]
#       2 y = [movie_DF('revenue')]
#       3 plt.plot(x, y)
#       4 plt.show
#
# TypeError: 'DataFrame' object is not callable

# %%
movieSheet.keys()
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
movie_df= pd.DataFrame(movieSheet, columns = ['title', 'budget', 'revenue'])
movie_df
# Out:
#                              title    budget      revenue
# 0                        Toy Story  30000000  373554033.0
# 1                          Jumanji  65000000  262797249.0
# 2                 Grumpier Old Men         0          0.0
# 3                Waiting to Exhale  16000000   81452156.0
# 4      Father of the Bride Part II         0   76578911.0
# ...                            ...       ...          ...
# 45461                       Subdue         0          0.0
# 45462          Century of Birthing         0          0.0
# 45463                     Betrayal         0          0.0
# 45464             Satan Triumphant         0          0.0
# 45465                     Queerama         0          0.0
#
# [45466 rows x 3 columns]

# %%
movie = movie_df.groupby('title').count().sort_values('revenue', ascending = False)
movie
# Out:
#                           budget  revenue
# title
# Cinderella                    11       11
# Hamlet                         9        9
# Alice in Wonderland            9        9
# Les MisÃ©rables                8        8
# Beauty and the Beast           8        8
# ...                          ...      ...
# Hollywood Homicide             1        1
# Hollywood Hong Kong            1        1
# Hollywood Hot Tubs             1        1
# Hollywood Man                  1        1
# ãƒ•ã‚¡ãƒ³ã‚¿ã‚¹ãƒ†ã‚£ãƒ       1        1
#
# [42275 rows x 2 columns]

# %%
movieSheet.shape
# Out:
# (45466, 24)

# %%
modifiedMovies = movie_DF.iloc[:501,:24]

# %%
pd.DataFrame(modifiedMovies)
# Out:
#      adult                              belongs_to_collection    budget  \
# 0    FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1    FALSE                                                NaN  65000000
# 2    FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3    FALSE                                                NaN  16000000
# 4    FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ..     ...                                                ...       ...
# 496  FALSE                                                NaN         0
# 497  FALSE  {'id': 8580, 'name': 'The Karate Kid Collectio...  12000000
# 498  FALSE                                                NaN         0
# 499  FALSE                                                NaN  20000000
# 500  FALSE                                                NaN  40000000
#
#                                                 genres  \
# ...

# %%
movieTitles = modifiedMovies.sort_values(by="revenue", ascending=False).head(501)
movieTitles
# Out:
#      adult                              belongs_to_collection    budget  \
# 475  FALSE  {'id': 328, 'name': 'Jurassic Park Collection'...  63000000
# 359  FALSE  {'id': 94032, 'name': 'The Lion King Collectio...  45000000
# 256  FALSE  {'id': 10, 'name': 'Star Wars Collection', 'po...  11000000
# 351  FALSE                                                NaN  55000000
# 495  FALSE                                                NaN  25000000
# ..     ...                                                ...       ...
# 319  FALSE                                                NaN        32
# 320  FALSE                                                NaN         0
# 321  FALSE                                                NaN         0
# 126  FALSE                                                NaN         0
# 500  FALSE                                                NaN  40000000
#
#                                                 genres  \
# ...

# %%
moviePopularity = modifiedMovies.sort_values(by="popularity", ascending=False).head(21)
moviePopularity
# Out:
#      adult                              belongs_to_collection     budget  \
# 292  FALSE                                                NaN    8000000
# 314  FALSE                                                NaN   25000000
# 351  FALSE                                                NaN   55000000
# 256  FALSE  {'id': 10, 'name': 'Star Wars Collection', 'po...   11000000
# 0    FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...   30000000
# 359  FALSE  {'id': 94032, 'name': 'The Lion King Collectio...   45000000
# 108  FALSE                                                NaN   72000000
# 289  FALSE                                                NaN   16000000
# 147  FALSE                                                NaN   52000000
# 46   FALSE                                                NaN   33000000
# 5    FALSE                                                NaN   60000000
# 405  FALSE  {'id': 11716, 'name': 'Addams Family Collectio...          0
# ...

# %%
plt.figure(figsize = (15, 5))
plt.xticks(rotation = 90, fontsize = 'large')
sns.barplot(x='title', data = moviePopularity,  y = 'popularity',)
# Out:
# <AxesSubplot:xlabel='title', ylabel='popularity'>
